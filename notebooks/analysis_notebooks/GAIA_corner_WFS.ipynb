# %%
import sys
sys.path.append('../analysis_tools/')
import analysisTools as at 
data_dir = '/epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/\
analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/'
import imp
imp.reload(at)
# Out:
# <module 'analysisTools' from '../analysis_tools/analysisTools.py'>

# %% [markdown]
# Show the simulated GAIA DR2 catalog used as a PhoSim input at the locations of corner wavefront sensors.

# %%
images = {}
for sensor in ['R00_S22', 'R40_S02', 'R44_S00', 'R04_S20']:
    raft = sensor[:3]
    detector = sensor[-3:]
    print(raft,detector)
    images[sensor] = at.readPostISRImage(data_dir, focalType = 'intra', 
                                         raft = raft, detector = detector,)
# Out:
# R00 S22
# data_id is
# {'visit': 9006002, 'filter': 'g', 'raftName': 'R00', 'detectorName': 'S22', 'detector': 197}
# Done
#
# R40 S02
# data_id is
# {'visit': 9006002, 'filter': 'g', 'raftName': 'R40', 'detectorName': 'S02', 'detector': 209}
# Done
#
# R44 S00
# data_id is
# {'visit': 9006002, 'filter': 'g', 'raftName': 'R44', 'detectorName': 'S00', 'detector': 216}
# Done
#
# R04 S20
# data_id is
# {'visit': 9006002, 'filter': 'g', 'raftName': 'R04', 'detectorName': 'S20', 'detector': 204}
# Done

# %% [markdown]
# Currently the simulated images are available for the 'high' galactic latitude.

# %%
# %matplotlib inline

fig, axs = plt.subplots(2,2,figsize=(15,15))
ax = np.ravel(axs)

i = 0 
for sensor in ['R04_S20', 'R44_S00', 'R00_S22', 'R40_S02']:
    img = ax[i].imshow(images[sensor].T, origin='lower', vmax=1200)
    ax[i].set_title('sensor %s'%sensor, fontsize=18)
    i += 1 

plt.tight_layout()

plt.savefig('GAIA_DR2_high_corner_sensors2.png', bbox_inches='tight')

# %%
pwd
# Out:
# '/data/epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_notebooks'

# %%
# %matplotlib inline
at.plotImage(image,ax=None, log=True, sensor='R00_S22', focalType='intra',
          starMarker='redCross',starMarkerArgs=None,
          centMarkerArgs = None,centMarker='redCross',plotArgs={'vmin':1, 'vmax':2.3})

# %% [markdown]
# plot postage stamps :

# %%
import imp
imp.reload(at)
focalType='intra'
for sensor in  ['R04_S20', 'R44_S00', 'R00_S22', 'R40_S02']:
    at.plotPostageStamps(data_dir, sensor=sensor, focalType=focalType, Nstars=4
                        )
# Out:
# Using postage images from /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/postage
# Searching in /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/postage directory
#
# Available postage stamp images for sensor R04_S20:
#
# Looking for files that start with "intra_singleSciImg" and contain "R04_S20"...
#
# Found 2 singleSciImg postage stamp images
# ['intra_singleSciImg_sensor-R04_S20_C0_star-0_id-1_posX-254_posY-2517.txt', 'intra_singleSciImg_sensor-R04_S20_C0_star-0_id-10_posX-913_posY-1304.txt']
#
# Looking for files that start with "intra_imgDeblend_full" and contain "R04_S20"...
#
# Found 2 imgDeblend_full postage stamp images
# ['intra_imgDeblend_full_sensor-R04_S20_C0_star-0_id-1_posX-254_posY-2517.txt', 'intra_imgDeblend_full_sensor-R04_S20_C0_star-0_id-10_posX-913_posY-1304.txt']
#
# Looking for files that start with "intra_imgDeblend_resized" and contain "R04_S20"...
#
# Found 2 imgDeblend_resized postage stamp images
# ['intra_imgDeblend_resized_sensor-R04_S20_C0_star-0_id-1_posX-254_posY-2517.txt', 'intra_imgDeblend_resized_sensor-R04_S20_C0_star-0_id-10_posX-913_posY-1304.txt']
# Only found 2
# Loading intra_singleSciImg_sensor-R04_S20_C0_star-0_id-1_posX-254_posY-2517.txt
# Loading intra_singleSciImg_sensor-R04_S20_C0_star-0_id-10_posX-913_posY-1304.txt
# Loading intra_imgDeblend_full_sensor-R04_S20_C0_star-0_id-1_posX-254_posY-2517.txt
# Loading intra_imgDeblend_full_sensor-R04_S20_C0_star-0_id-10_posX-913_posY-1304.txt
# Loading intra_imgDeblend_resized_sensor-R04_S20_C0_star-0_id-1_posX-254_posY-2517.txt
# Loading intra_imgDeblend_resized_sensor-R04_S20_C0_star-0_id-10_posX-913_posY-1304.txt
# Using postage images from /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/postage
# Searching in /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/postage directory
#
# Available postage stamp images for sensor R44_S00:
#
# Looking for files that start with "intra_singleSciImg" and contain "R44_S00"...
#
# Found 4 singleSciImg postage stamp images
# ['intra_singleSciImg_sensor-R44_S00_C0_star-0_id-4_posX-1556_posY-1899.txt', 'intra_singleSciImg_sensor-R44_S00_C0_star-1_id-5_posX-673_posY-2046.txt', 'intra_singleSciImg_sensor-R44_S00_C0_star-0_id-12_posX-1308_posY-1933.txt', 'intra_singleSciImg_sensor-R44_S00_C0_star-1_id-13_posX-1661_posY-466.txt']
#
# Looking for files that start with "intra_imgDeblend_full" and contain "R44_S00"...
#
# Found 4 imgDeblend_full postage stamp images
# ['intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-4_posX-1556_posY-1899.txt', 'intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-5_posX-673_posY-2046.txt', 'intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-12_posX-1308_posY-1933.txt', 'intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-13_posX-1661_posY-466.txt']
#
# Looking for files that start with "intra_imgDeblend_resized" and contain "R44_S00"...
#
# Found 4 imgDeblend_resized postage stamp images
# ['intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-4_posX-1556_posY-1899.txt', 'intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-5_posX-673_posY-2046.txt', 'intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-12_posX-1308_posY-1933.txt', 'intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-13_posX-1661_posY-466.txt']
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-0_id-4_posX-1556_posY-1899.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-1_id-5_posX-673_posY-2046.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-0_id-12_posX-1308_posY-1933.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-1_id-13_posX-1661_posY-466.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-4_posX-1556_posY-1899.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-5_posX-673_posY-2046.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-12_posX-1308_posY-1933.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-13_posX-1661_posY-466.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-4_posX-1556_posY-1899.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-5_posX-673_posY-2046.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-12_posX-1308_posY-1933.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-13_posX-1661_posY-466.txt
# Using postage images from /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/postage
# Searching in /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/postage directory
#
# Available postage stamp images for sensor R00_S22:
#
# Looking for files that start with "intra_singleSciImg" and contain "R00_S22"...
#
# Found 4 singleSciImg postage stamp images
# ['intra_singleSciImg_sensor-R00_S22_C0_star-0_id-6_posX-1722_posY-297.txt', 'intra_singleSciImg_sensor-R00_S22_C0_star-0_id-7_posX-1721_posY-296.txt', 'intra_singleSciImg_sensor-R00_S22_C0_star-1_id-8_posX-696_posY-2309.txt', 'intra_singleSciImg_sensor-R00_S22_C0_star-2_id-9_posX-451_posY-1772.txt']
#
# Looking for files that start with "intra_imgDeblend_full" and contain "R00_S22"...
#
# Found 4 imgDeblend_full postage stamp images
# ['intra_imgDeblend_full_sensor-R00_S22_C0_star-0_id-6_posX-1722_posY-297.txt', 'intra_imgDeblend_full_sensor-R00_S22_C0_star-0_id-7_posX-1721_posY-296.txt', 'intra_imgDeblend_full_sensor-R00_S22_C0_star-1_id-8_posX-696_posY-2309.txt', 'intra_imgDeblend_full_sensor-R00_S22_C0_star-2_id-9_posX-451_posY-1772.txt']
#
# Looking for files that start with "intra_imgDeblend_resized" and contain "R00_S22"...
#
# Found 4 imgDeblend_resized postage stamp images
# ['intra_imgDeblend_resized_sensor-R00_S22_C0_star-0_id-6_posX-1722_posY-297.txt', 'intra_imgDeblend_resized_sensor-R00_S22_C0_star-0_id-7_posX-1721_posY-296.txt', 'intra_imgDeblend_resized_sensor-R00_S22_C0_star-1_id-8_posX-696_posY-2309.txt', 'intra_imgDeblend_resized_sensor-R00_S22_C0_star-2_id-9_posX-451_posY-1772.txt']
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-0_id-6_posX-1722_posY-297.txt
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-0_id-7_posX-1721_posY-296.txt
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-1_id-8_posX-696_posY-2309.txt
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-2_id-9_posX-451_posY-1772.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-0_id-6_posX-1722_posY-297.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-0_id-7_posX-1721_posY-296.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-1_id-8_posX-696_posY-2309.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-2_id-9_posX-451_posY-1772.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-0_id-6_posX-1722_posY-297.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-0_id-7_posX-1721_posY-296.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-1_id-8_posX-696_posY-2309.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-2_id-9_posX-451_posY-1772.txt
# Using postage images from /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/postage
# Searching in /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_high_gt11_WFS_wide/postage directory
#
# Available postage stamp images for sensor R40_S02:
#
# Looking for files that start with "intra_singleSciImg" and contain "R40_S02"...
#
# Found 2 singleSciImg postage stamp images
# ['intra_singleSciImg_sensor-R40_S02_C0_star-0_id-9_posX-557_posY-3383.txt', 'intra_singleSciImg_sensor-R40_S02_C0_star-0_id-11_posX-557_posY-3383.txt']
#
# Looking for files that start with "intra_imgDeblend_full" and contain "R40_S02"...
#
# Found 2 imgDeblend_full postage stamp images
# ['intra_imgDeblend_full_sensor-R40_S02_C0_star-0_id-9_posX-557_posY-3383.txt', 'intra_imgDeblend_full_sensor-R40_S02_C0_star-0_id-11_posX-557_posY-3383.txt']
#
# Looking for files that start with "intra_imgDeblend_resized" and contain "R40_S02"...
#
# Found 2 imgDeblend_resized postage stamp images
# ['intra_imgDeblend_resized_sensor-R40_S02_C0_star-0_id-9_posX-557_posY-3383.txt', 'intra_imgDeblend_resized_sensor-R40_S02_C0_star-0_id-11_posX-557_posY-3383.txt']
# Only found 2
# Loading intra_singleSciImg_sensor-R40_S02_C0_star-0_id-9_posX-557_posY-3383.txt
# Loading intra_singleSciImg_sensor-R40_S02_C0_star-0_id-11_posX-557_posY-3383.txt
# Loading intra_imgDeblend_full_sensor-R40_S02_C0_star-0_id-9_posX-557_posY-3383.txt
# Loading intra_imgDeblend_full_sensor-R40_S02_C0_star-0_id-11_posX-557_posY-3383.txt
# Loading intra_imgDeblend_resized_sensor-R40_S02_C0_star-0_id-9_posX-557_posY-3383.txt
# Loading intra_imgDeblend_resized_sensor-R40_S02_C0_star-0_id-11_posX-557_posY-3383.txt
