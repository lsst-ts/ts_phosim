# %% [markdown]
# # postISR on WFS corner sensors using bscDbType:file

# %%
import os

# %%
# to reload WepController after some code editing,
# need to run the code below - 
# it tells python to remove the name binding. 
# Python searches sys.modules to see whether 
# the modules had already been imported,
# and if they had, they are not reloaded 
import sys
# del sys.modules['lsst.ts.wep.WepController']
# del sys.modules['lsst.ts.wep.ctrlIntf.WEPCalculationFactory']

from lsst.ts.wep.WepController import WepController
from lsst.ts.wep.ctrlIntf.WEPCalculationFactory import WEPCalculationFactory

# mostly from runCloseLoopPostISR.py 
from lsst.ts.wep.Utility import CamType, FilterType, getModulePath, mapFilterRefToG, DefocalType

# %% [markdown]
# Just to be sure, remove the old database, which would still be there if we didn't finish the loop

# %%
path_to_ts_wep = '/epyc/users/suberlak/Commissioning/aos/ts_wep/'
bscDataDir = os.path.join(path_to_ts_wep, 'tests/testData')
dbFile = 'bsc.db3'
if dbFile  in os.listdir(bscDataDir):
    os.remove(os.path.join(bscDataDir,dbFile))
    print('Removed old %s file'%dbFile)
# Out:
# Removed old bsc.db3 file

# %%
import sys
sys.path.append('../analysis_tools/')
import analysisTools as at

# %%
topDir = '/epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/'
closed_loop_input_dir = os.path.join(topDir,'dr2_med_full_2020_24_wideWFS/input/')
raInDeg, decInDeg = at.getRaDecFromGaiaField('med')
# Out:
# For this field, the raInDeg=233.017, decInDeg=-4.447

# %% [markdown]
# Need to manually change the setting in `policy/default.yaml` , because there is no way to force `ts_wep` to actually instantiate the `wep_calculator` while using a different settings file ...

# %%
# what bscDbType do we want to use ? 
bscDbType = 'file'

from lsst.ts.wep.ParamReader import ParamReader
settingFilePath = os.path.join(path_to_ts_wep, 'policy/default.yaml')
settingFile = ParamReader(filePath=settingFilePath)
print('Before change: ', settingFile.getSetting("bscDbType"))


# In the following we update the setting for bscDbType saving the change in the default.yaml file 
settingFile.updateSetting("bscDbType", bscDbType)
settingFile.saveSetting(filePath=settingFilePath)

# check that the change indeed took place 
settingFilePath = os.path.join(path_to_ts_wep, 'policy/default.yaml')
settingFile = ParamReader(filePath=settingFilePath)
print('After change: ', settingFile.getSetting("bscDbType"))
# Out:
# Before change:  refCat
# After change:  file

# %%
print('Using %s '%closed_loop_input_dir )

# these are basically parts of WEPCalculationFactory.py  calculateWavefrontErrors()
# skipping the ingest and ISR 
wep_calc = WEPCalculationFactory.getCalculator(CamType.LsstCam, closed_loop_input_dir)
wep_calc.wepCntlr.setPostIsrCcdInputs(os.path.join(closed_loop_input_dir, 'rerun/run1'))
rotAngInDeg = 0.0
skyFile  = os.path.join(closed_loop_input_dir[:-len('\input')], 'iter0/pert/skyLsstCamInfo.txt')
wep_calc.setSkyFile(skyFile)
wep_calc.setBoresight(raInDeg, decInDeg)
wep_calc.setRotAng(rotAngInDeg)
        
obsIdList = [9006002]
neighborStarMap = wep_calc._getTargetStar(obsIdList, defocalState=DefocalType.Intra)
# Out:
# Using /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/

# %%
from lsst.ts.wep.Utility import FilterType

    
###
# below are parts of _calcWfErr() that we are testing : 
###
sensorNameList = list(neighborStarMap)
# detector_list = sensorNameList
isrImgMap = wep_calc.wepCntlr.getPostIsrImgMapOnCornerWfs(sensorNameList, obsIdList[0])

doDeblending = False # wep_calc.settingFile.getSetting("doDeblending")

postageImgDir = os.path.join(closed_loop_input_dir, 'postage')
if not os.path.exists(postageImgDir):
    os.makedirs(postageImgDir)


donutMap = wep_calc.wepCntlr.getDonutMap(neighborStarMap, isrImgMap, FilterType.REF,
                                         doDeblending=doDeblending, 
                                         postageImg=True,postageImgDir=postageImgDir)
    
print('done')
# Out:
# R:0,0 S:2,2,A is intra-focal
# R:0,4 S:2,0,A is intra-focal
# R:4,0 S:0,2,A is intra-focal
# R:4,4 S:0,0,A is intra-focal
# R:0,0 S:2,2,B is extra-focal
# R:0,4 S:2,0,B is extra-focal
# R:4,0 S:0,2,B is extra-focal
# R:4,4 S:0,0,B is extra-focal
#
#  Calculating the donut map
# Saving postage stamp images in /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/postage
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-0_id-1014_posX-142_posY-286.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-2_id-1961_posX-949_posY-1516.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-3_id-2078_posX-794_posY-3443.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-4_id-2084_posX-1276_posY-3481.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-5_id-3681_posX-6_posY-736.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-6_id-3918_posX-311_posY-0.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-7_id-4047_posX-873_posY-2646.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R00_S22_C0_star-7_id-4047_posX-873_posY-2646.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R00_S22_C0_star-7_id-4047_posX-873_posY-2646.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-8_id-4458_posX-0_posY-3724.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R00_S22_C0_star-9_id-5317_posX-142_posY-286.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R04_S20_C0_star-0_id-8414_posX-366_posY-2897.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R04_S20_C0_star-1_id-9298_posX-904_posY-0.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R04_S20_C0_star-1_id-9298_posX-904_posY-0.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R04_S20_C0_star-1_id-9298_posX-904_posY-0.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R04_S20_C0_star-2_id-9316_posX-879_posY-1516.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R04_S20_C0_star-2_id-9316_posX-879_posY-1516.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R04_S20_C0_star-2_id-9316_posX-879_posY-1516.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R04_S20_C0_star-3_id-9318_posX-1016_posY-1806.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R04_S20_C0_star-3_id-9318_posX-1016_posY-1806.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R04_S20_C0_star-3_id-9318_posX-1016_posY-1806.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-0_id-11771_posX-929_posY-3608.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-1_id-11799_posX-979_posY-1479.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-2_id-11804_posX-1135_posY-1024.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-3_id-11808_posX-940_posY-692.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-4_id-14612_posX-1476_posY-3303.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R40_S02_C0_star-4_id-14612_posX-1476_posY-3303.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R40_S02_C0_star-4_id-14612_posX-1476_posY-3303.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-5_id-14896_posX-466_posY-2102.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R40_S02_C0_star-5_id-14896_posX-466_posY-2102.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R40_S02_C0_star-5_id-14896_posX-466_posY-2102.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-6_id-14906_posX-338_posY-654.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-7_id-15689_posX-212_posY-493.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R40_S02_C0_star-8_id-16341_posX-783_posY-1173.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R44_S00_C0_star-2_id-18790_posX-1267_posY-2575.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R44_S00_C0_star-2_id-18790_posX-1267_posY-2575.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R44_S00_C0_star-2_id-18790_posX-1267_posY-2575.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R44_S00_C0_star-3_id-19294_posX-0_posY-1155.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R44_S00_C0_star-4_id-19394_posX-741_posY-2896.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R44_S00_C0_star-4_id-19394_posX-741_posY-2896.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R44_S00_C0_star-4_id-19394_posX-741_posY-2896.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R44_S00_C0_star-5_id-19399_posX-318_posY-2959.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R44_S00_C0_star-6_id-19400_posX-92_posY-3101.txt
# Saving postage stamp image as intra_imgDeblend_full_sensor-R44_S00_C0_star-6_id-19400_posX-92_posY-3101.txt
# Saving postage stamp image as intra_imgDeblend_resized_sensor-R44_S00_C0_star-6_id-19400_posX-92_posY-3101.txt
#
# Saving postage stamp as intra_singleSciImg_sensor-R44_S00_C0_star-7_id-19609_posX-1567_posY-0.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R00_S22_C1_star-0_id-1027_posX-448_posY-520.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R00_S22_C1_star-1_id-1030_posX-943_posY-441.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R00_S22_C1_star-1_id-1030_posX-943_posY-441.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R00_S22_C1_star-1_id-1030_posX-943_posY-441.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R00_S22_C1_star-2_id-1598_posX-27_posY-1964.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R00_S22_C1_star-3_id-1614_posX-1862_posY-2145.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R00_S22_C1_star-3_id-1614_posX-1862_posY-2145.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R00_S22_C1_star-3_id-1614_posX-1862_posY-2145.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R00_S22_C1_star-4_id-2091_posX-362_posY-3582.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R00_S22_C1_star-4_id-2091_posX-362_posY-3582.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R00_S22_C1_star-4_id-2091_posX-362_posY-3582.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R00_S22_C1_star-5_id-2724_posX-0_posY-1204.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R00_S22_C1_star-6_id-5337_posX-357_posY-114.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R04_S20_C1_star-0_id-7597_posX-1131_posY-1557.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R04_S20_C1_star-1_id-7603_posX-1191_posY-2677.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R04_S20_C1_star-1_id-7603_posX-1191_posY-2677.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R04_S20_C1_star-1_id-7603_posX-1191_posY-2677.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R04_S20_C1_star-2_id-7609_posX-1223_posY-3204.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R04_S20_C1_star-3_id-8193_posX-1543_posY-3179.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R04_S20_C1_star-4_id-8782_posX-1146_posY-360.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R04_S20_C1_star-4_id-8782_posX-1146_posY-360.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R04_S20_C1_star-4_id-8782_posX-1146_posY-360.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R04_S20_C1_star-5_id-9528_posX-1840_posY-2724.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R04_S20_C1_star-5_id-9528_posX-1840_posY-2724.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R04_S20_C1_star-5_id-9528_posX-1840_posY-2724.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R04_S20_C1_star-6_id-10193_posX-0_posY-3756.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R40_S02_C1_star-0_id-12791_posX-336_posY-547.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R40_S02_C1_star-1_id-13548_posX-0_posY-3675.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R40_S02_C1_star-2_id-13573_posX-0_posY-814.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R40_S02_C1_star-2_id-13573_posX-0_posY-814.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R40_S02_C1_star-2_id-13573_posX-0_posY-814.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R40_S02_C1_star-3_id-14361_posX-1512_posY-1244.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R40_S02_C1_star-3_id-14361_posX-1512_posY-1244.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R40_S02_C1_star-3_id-14361_posX-1512_posY-1244.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R40_S02_C1_star-4_id-14770_posX-1821_posY-1812.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R40_S02_C1_star-4_id-14770_posX-1821_posY-1812.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R40_S02_C1_star-4_id-14770_posX-1821_posY-1812.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R44_S00_C1_star-0_id-19274_posX-298_posY-1128.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R44_S00_C1_star-1_id-19599_posX-1187_posY-31.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R44_S00_C1_star-2_id-20033_posX-1765_posY-2378.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R44_S00_C1_star-3_id-21319_posX-1474_posY-1682.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R44_S00_C1_star-3_id-21319_posX-1474_posY-1682.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R44_S00_C1_star-3_id-21319_posX-1474_posY-1682.txt
#
# Saving postage stamp as extra_singleSciImg_sensor-R44_S00_C1_star-4_id-21328_posX-596_posY-1736.txt
# Saving postage stamp image as extra_imgDeblend_full_sensor-R44_S00_C1_star-4_id-21328_posX-596_posY-1736.txt
# Saving postage stamp image as extra_imgDeblend_resized_sensor-R44_S00_C1_star-4_id-21328_posX-596_posY-1736.txt
# done

# %% [markdown]
# Plot these postage stamps :

# %%
# %matplotlib inline
import imp
imp.reload(at)
postage_dir= os.path.join(closed_loop_input_dir, 'postage')
at.plotPostageStamps(postage_dir, sensor='R00_S22', focalType='intra', Nstars=None,
                     testLabel='gaia')
# Out:
# Using postage images from /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/postage
# Searching in /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/postage directory
#
# Available postage stamp images for sensor R00_S22:
#
# Looking for files that start with "intra_singleSciImg" and contain "R00_S22"...
#
# Found 13 singleSciImg postage stamp images
# first 5:
# ['intra_singleSciImg_sensor-R00_S22_C0_star-0_id-12_posX-824_posY-813.txt', 'intra_singleSciImg_sensor-R00_S22_C0_star-1_id-13_posX-740_posY-1402.txt', 'intra_singleSciImg_sensor-R00_S22_C0_star-2_id-14_posX-613_posY-3765.txt', 'intra_singleSciImg_sensor-R00_S22_C0_star-0_id-1014_posX-142_posY-286.txt', 'intra_singleSciImg_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt']
#
# Looking for files that start with "intra_imgDeblend_full" and contain "R00_S22"...
#
# Found 5 imgDeblend_full postage stamp images
# ['intra_imgDeblend_full_sensor-R00_S22_C0_star-0_id-12_posX-824_posY-813.txt', 'intra_imgDeblend_full_sensor-R00_S22_C0_star-1_id-13_posX-740_posY-1402.txt', 'intra_imgDeblend_full_sensor-R00_S22_C0_star-2_id-14_posX-613_posY-3765.txt', 'intra_imgDeblend_full_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt', 'intra_imgDeblend_full_sensor-R00_S22_C0_star-7_id-4047_posX-873_posY-2646.txt']
#
# Looking for files that start with "intra_imgDeblend_resized" and contain "R00_S22"...
#
# Found 5 imgDeblend_resized postage stamp images
# ['intra_imgDeblend_resized_sensor-R00_S22_C0_star-0_id-12_posX-824_posY-813.txt', 'intra_imgDeblend_resized_sensor-R00_S22_C0_star-1_id-13_posX-740_posY-1402.txt', 'intra_imgDeblend_resized_sensor-R00_S22_C0_star-2_id-14_posX-613_posY-3765.txt', 'intra_imgDeblend_resized_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt', 'intra_imgDeblend_resized_sensor-R00_S22_C0_star-7_id-4047_posX-873_posY-2646.txt']
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-0_id-12_posX-824_posY-813.txt
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-1_id-13_posX-740_posY-1402.txt
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-2_id-14_posX-613_posY-3765.txt
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-0_id-1014_posX-142_posY-286.txt
# Loading intra_singleSciImg_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-0_id-12_posX-824_posY-813.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-1_id-13_posX-740_posY-1402.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-2_id-14_posX-613_posY-3765.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt
# Loading intra_imgDeblend_full_sensor-R00_S22_C0_star-7_id-4047_posX-873_posY-2646.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-0_id-12_posX-824_posY-813.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-1_id-13_posX-740_posY-1402.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-2_id-14_posX-613_posY-3765.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-1_id-1021_posX-1748_posY-551.txt
# Loading intra_imgDeblend_resized_sensor-R00_S22_C0_star-7_id-4047_posX-873_posY-2646.txt
# ../analysis_tools/analysisTools.py:448: UserWarning: loadtxt: Empty input file: "/epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/postage/intra_imgDeblend_resized_sensor-R00_S22_C0_star-7_id-4047_posX-873_posY-2646.txt"
#   image = np.loadtxt(os.path.join(postage_dir,fname))

# %% [markdown]
# There are some donuts, but some are empty locations....The question why would be related to how `LocalDatabaseForStarFile` works...

# %%
wep_calc._getBscDbType()
# Out:
# <BscDbType.LocalDbForStarFile: 2>

# %%
# now pass the donutMap to WepController to calculate wavefront error :
donutMap2 = wep_calc.wepCntlr.calcWfErr(donutMap,postageImgDir)
# Out:
#  Calculating the wavefront error based on the donut map
#
#  sensorName  R:4,0 S:0,2,A  abbrevDetectorName  R40_S02_C0  starId= 14896  donut px pos =  (593.0272911778382, 2226.4795601960527)
#
#  sensorName  R:4,4 S:0,0,A  abbrevDetectorName  R44_S00_C0  starId= 16864  donut px pos =  (146.76854488294006, 3686.945107035047)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-3a012420325f> in <module>
#       1 # now pass the donutMap to WepController to calculate wavefront error :
# ----> 2 donutMap2 = wep_calc.wepCntlr.calcWfErr(donutMap,postageImgDir)
#
# /astro/store/epyc/users/suberlak/Commissioning/aos/ts_wep/python/lsst/ts/wep/WepController.py in calcWfErr(self, donutMap, postageImgDir)
#     695                                 # Calculate the wavefront error
#     696 				zer4UpNm = self._calcSglWfErr(intraImg, extraImg, intraFieldXY,
# --> 697 											  extraFieldXY)
#     698
#     699                                 # Put the value to the donut image
#
# /astro/store/epyc/users/suberlak/Commissioning/aos/ts_wep/python/lsst/ts/wep/WepController.py in _calcSglWfErr(self, intraImg, extraImg, intraFieldXY, extraFieldXY)
#     746
#     747                 # Calculate the wavefront error
# --> 748                 zer4UpNm = self.wfEsti.calWfsErr()
#     749
#     750                 return zer4UpNm
#
# /astro/store/epyc/users/suberlak/Commissioning/aos/ts_wep/python/lsst/ts/wep/WfEstimator.py in calWfsErr(self, tol, showZer, showPlot)
#     210             if (d1 != self.sizeInPix) or (d2 != self.sizeInPix):
#     211                 raise RuntimeError("Input image shape is (%d, %d), not required (%d, %d)" % (
# --> 212                     d1, d2, self.sizeInPix, self.sizeInPix))
#     213
#     214         # Calculate the wavefront error.
#
# RuntimeError: Input image shape is (0, 0), not required (160, 160)

# %%
at.plotPostageStamps(postage_dir, sensor='R44_S00', focalType='intra', Nstars=None,
                     testLabel='gaia')
# Out:
# Using postage images from /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/postage
# Searching in /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/postage directory
#
# Available postage stamp images for sensor R44_S00:
#
# Looking for files that start with "intra_singleSciImg" and contain "R44_S00"...
#
# Found 11 singleSciImg postage stamp images
# first 5:
# ['intra_singleSciImg_sensor-R44_S00_C0_star-0_id-21_posX-273_posY-30.txt', 'intra_singleSciImg_sensor-R44_S00_C0_star-1_id-22_posX-760_posY-3619.txt', 'intra_singleSciImg_sensor-R44_S00_C0_star-2_id-23_posX-521_posY-2818.txt', 'intra_singleSciImg_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt', 'intra_singleSciImg_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt']
#
# Looking for files that start with "intra_imgDeblend_full" and contain "R44_S00"...
#
# Found 8 imgDeblend_full postage stamp images
# first 5:
# ['intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-21_posX-273_posY-30.txt', 'intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-22_posX-760_posY-3619.txt', 'intra_imgDeblend_full_sensor-R44_S00_C0_star-2_id-23_posX-521_posY-2818.txt', 'intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt', 'intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt']
#
# Looking for files that start with "intra_imgDeblend_resized" and contain "R44_S00"...
#
# Found 8 imgDeblend_resized postage stamp images
# first 5:
# ['intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-21_posX-273_posY-30.txt', 'intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-22_posX-760_posY-3619.txt', 'intra_imgDeblend_resized_sensor-R44_S00_C0_star-2_id-23_posX-521_posY-2818.txt', 'intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt', 'intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt']
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-0_id-21_posX-273_posY-30.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-1_id-22_posX-760_posY-3619.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-2_id-23_posX-521_posY-2818.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-2_id-18790_posX-1267_posY-2575.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-3_id-19294_posX-0_posY-1155.txt
# Loading intra_singleSciImg_sensor-R44_S00_C0_star-4_id-19394_posX-741_posY-2896.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-21_posX-273_posY-30.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-22_posX-760_posY-3619.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-2_id-23_posX-521_posY-2818.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-2_id-18790_posX-1267_posY-2575.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-4_id-19394_posX-741_posY-2896.txt
# Loading intra_imgDeblend_full_sensor-R44_S00_C0_star-6_id-19400_posX-92_posY-3101.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-21_posX-273_posY-30.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-22_posX-760_posY-3619.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-2_id-23_posX-521_posY-2818.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-0_id-16864_posX-106_posY-3648.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-1_id-17897_posX-724_posY-793.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-2_id-18790_posX-1267_posY-2575.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-4_id-19394_posX-741_posY-2896.txt
# Loading intra_imgDeblend_resized_sensor-R44_S00_C0_star-6_id-19400_posX-92_posY-3101.txt

# %% [markdown]
# So it's the same problem whether we have `doDeblending:False` or `True`

# %% [markdown]
# ## NEXT :

# %%
#
# TO DO : final steps 
#
wfs_zer_output = 'wfs.gaia.corner.txt'

listOfWfErr = wep_calc._populateListOfSensorWavefrontData(donutMap2)

zerDict = {}
for wfErrObj in listOfWfErr:
    zerDict[wfErrObj.getSensorId()] = wfErrObj.getAnnularZernikePoly()

sensorKeys = list(zerDict.keys())
sensorKeys.sort()

zerList = []
for sensorKey in sensorKeys:
    zerList.append(zerDict[sensorKey])
zerArray = np.array(zerList)

wfs_output_path = os.path.join(closed_loop_input_dir, wfs_zer_output)
np.savetxt(wfs_output_path, zerArray, header='The following are ZK in um from z4 to z22:')
print('WFS Zernike results saved as %s'%(wfs_output_path))

# %% [markdown]
# Show the Zernike errors :

# %%
data_dir = closed_loop_input_dir[:-6]
opdZkFilePath = os.path.join(data_dir,  'iter0/img/opd.zer.gaia')
opdData = np.loadtxt(opdZkFilePath)


# new results, bscDbType: image, new ISR 
wfsZkFilePath1 = os.path.join(closed_loop_input_dir, 'wfs.gaia.corner.txt')
wfsData1 = np.loadtxt(wfsZkFilePath1)

# %% [markdown]
# ### Plot all the corner wavefront sensors simulated with GAIA DR2 catalog:

# %%
images = {}
for sensor in ['R00_S22', 'R40_S02', 'R44_S00', 'R04_S20']:
    raft = sensor[:3]
    detector = sensor[-3:]
    print(raft,detector)
    images[sensor] = at.readPostISRImage(data_dir, focalType = 'intra', 
                                         raft = raft, detector = detector,)
# Out:
# R00 S22
# data_id is
# {'visit': 9006002, 'filter': 'g', 'raftName': 'R00', 'detectorName': 'S22', 'detector': 197}
# Reading postISR images from the following repo_dir:
# /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/rerun/run1
# Done
#
# R40 S02
# data_id is
# {'visit': 9006002, 'filter': 'g', 'raftName': 'R40', 'detectorName': 'S02', 'detector': 209}
# Reading postISR images from the following repo_dir:
# /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/rerun/run1
# Done
#
# R44 S00
# data_id is
# {'visit': 9006002, 'filter': 'g', 'raftName': 'R44', 'detectorName': 'S00', 'detector': 216}
# Reading postISR images from the following repo_dir:
# /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/rerun/run1
# Done
#
# R04 S20
# data_id is
# {'visit': 9006002, 'filter': 'g', 'raftName': 'R04', 'detectorName': 'S20', 'detector': 204}
# Reading postISR images from the following repo_dir:
# /epyc/users/suberlak/Commissioning/aos/ts_phosim/notebooks/analysis_scripts/results_gaia/dr2_med_full_2020_24_wideWFS/input/rerun/run1
# Done

# %%
# %matplotlib inline

fig, axs = plt.subplots(2,2,figsize=(15,15))
ax = np.ravel(axs)

i = 0 
for sensor in ['R04_S20', 'R44_S00', 'R00_S22', 'R40_S02']:
    img = ax[i].imshow(images[sensor].T, origin='lower', vmax=1200)
    ax[i].set_title('sensor %s'%sensor, fontsize=18)
    i += 1 

plt.tight_layout()

plt.savefig('GAIA_DR2_med_corner_sensors.png', bbox_inches='tight')
